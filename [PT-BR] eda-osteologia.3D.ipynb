# %% [markdown]
# <a href="https://colab.research.google.com/github/joanats/EDA-3D-Osteologia/blob/main/%5BPT-BR%5D%20eda-osteologia.3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**A importância da Análise de Dados**

# %% [markdown]
# A **análise de dados** é um processo fundamental para extrair conhecimento a partir de informações brutas, permitindo identificar padrões, tendências e relações que auxiliam na tomada de decisão. Seja em negócios, ciência ou tecnologia, **a capacidade de interpretar dados de forma eficiente se tornou essencial.**
#
# Por meio de técnicas estatísticas, computacionais e visuais, é possível responder a perguntas como o que aconteceu, quais fatores influenciaram determinado resultado e quais insights podem ser extraídos para otimizar processos.
#
# Neste projeto, realizarei uma análise exploratória de dados (EDA), utilizando diferentes abordagens para entender melhor o conjunto de informações e apresentar conclusões baseadas em evidências.
#
# Uma boa Análise de Dados se estrutura em etapas sequenciais, geralmente representado como:

# %% [markdown]
# ![](https://i.imgur.com/ioCui9P.png)

# %% [markdown]
# Me chamo [Joana Trindade](https://www.linkedin.com/in/joanatrindade-/) e, neste projeto, realizarei uma análise de dados com foco na experiência dos alunos que utilizaram a plataforma web de osteologia do Laboratório de Anatomia e Patologia Animal (LAPA).
#
#  Para isso, aplicarei boas práticas de codificação e análise de dados, garantindo um processo claro e objetivo.

# %% [markdown]
# O **objetivo** é avaliar a percepção do conhecimento prático em osteologia equina e sua aplicabilidade após o uso do site [Hub Anatomia 3D](https://hubanatomia.ufape.edu.br) do Laboratório de Anatomia e Patologia Animal (LAPA) da Universidade Federal do Agreste de Pernambuco (UFAPE).

# %% [markdown]
# Logo, é importante temos em mente que:

# %% [markdown]
#   > Todos os discentes que responderam o formulário cursaram a disciplina de Anatomia Descritiva dos Animais Domésticos totalmente de forma presencial. Os discentes que cursaram Anatomia Descritiva nos semestres letivos 2023.1, 2024.1 e 2024.2, participaram da pesquisa que foi divulgada após aprovação do CEP/CONEP e aplicada no semestre de 2024.2. Os que responderam às perguntas do questionário aplicado estavam distribuídos do primeiro ao quarto período do curso de graduação em Medicina Veterinária.
#   Do número total de estudantes (56), 17 do semestre 2023.1, 16 do semestre 2024.1, e 23 do semestre 2024.2

# %% [markdown]
# ## **Entendimento do problema -**
# ###**Avaliação da Percepção da Aprendizagem Prática em Osteologia Equina com o uso do site Hub Anatomia 3D**

# %% [markdown]
# O ensino de osteologia equina enfrenta desafios relacionados à disponibilidade de peças anatômicas físicas e à necessidade de métodos mais acessíveis e interativos para o aprendizado prático. O site Hub Anatomia 3D do Laboratório de Anatomia e Patologia Animal (LAPA/UFAPE) foi desenvolvida como uma ferramenta complementar para auxiliar os alunos na visualização e compreensão das estruturas ósseas equinas.

# %% [markdown]
# Neste contexto, a realização de uma **análise exploratória dos dados** coletados junto aos alunos que utilizaram o site [Hub Anatomia 3D](https://hubanatomia.ufape.edu.br) do Laboratório de Anatomia e Patologia Animal (LAPA/UFAPE) é essencial para compreender o impacto da ferramenta no ensino de Anatomia Veterinária. Essa etapa é fundamental por diversas razões:
#
#
#
# * **Avaliar a efetividade do ensino:**  identificando como a plataforma contribuiu para a assimilação do conhecimento em osteologia equina.
# * **Detectar padrões de aprendizado:** analisando o engajamento dos alunos e as funcionalidades mais relevantes.
# * **Aprimorar a metodologia:** fornecendo insights para otimizar o uso de tecnologias no ensino anatômico.

# %% [markdown]
# ##**Análise Exploratória de Dados (EDA)**

# %% [markdown]
# Agora que já entendemos o problema, podemos começar nossa EDA!
#
#
# Essa etapa é essencial para extrair insights valiosos sobre a percepção dos alunos em relação ao aprendizado de osteologia equina com o uso do site Hub Anatomia 3D do LAPA/UFAPE.
#
# Para uma boa EDA é necessário seguir alguns passos composto pelas seis fases de entender, preparar, processar, analisar, compartilhar e agir.
#
# Seu objetivo é obter insights que impulsionem a tomada de decisões informadas.

# %% [markdown]
# ##**Dados obtidos**

# %% [markdown]
# Para entender o processo, vamos organizar os dados coletados na pesquisa, facilitando a análise e garantindo uma interpretação mais clara das informações.
#
# As colunas deste dataset são:

# %% [markdown]
# * Carimbo de data/hora
# *   Você concorda em participar dessa pesquisa?
# *   Em que semestre você cursou (ou está cursando) a disciplina de Anatomia Descritiva dos Animais Domésticos?
# *   Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?
# *   Sobre o conhecimento prático da osteologia equina
# * Ainda sobre o conhecimento prático sobre osteologia equina
# * Você já fez estágio(s) em alguma área da medicina veterinária?
# * Se tiver alguma dúvida e precisar revisar osteologia equina, por onde você começaria?
# * Para revisar o conteúdo prático de osteologia equina em qualquer época do curso e na vida profissional, você acha que
# * Você recomendaria o aplicativo de osteologia equina 3D do LAPA para outros estudantes e profissionais?'
# * Você acredita que o processamento 3D de outras estruturas anatômicas seria importante para o enriquecimento do estudo de anatomia na UFAPE?
# * Você já utilizou alguma outra plataforma de anatomia 3D?

# %% [markdown]
# ##**1 - Preparação do ambiente**

# %% [markdown]
# **1.1 - Importando as bibliotecas necessárias nessa etapa.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_excel('/content/osteologia_equina(respostas).xlsx')

# %% [markdown]
# Vamos fazer o levantamento da quantidade de estudantes e seus respectivos períodos letivos durante a aplicação do formulário.

# %%
contagem_semestre = df['Em que semestre você cursou (ou está cursando) a disciplina de Anatomia Descritiva dos Animais Domésticos?'].value_counts()
total_estudantes = len(df)


percentual_semestre = (contagem_semestre / total_estudantes) * 100

resultado = pd.DataFrame({
    'quantidade_estudantes': contagem_semestre,
    'percentual': percentual_semestre
})

resultado_resetado = resultado.reset_index()

resultado_resetado.columns = ['semestre', 'estudantes', 'percentual']

semestre_para_periodo = {
    '2024.2 (estou cursando)': '1° período',
    '2024.1 (semestre passado)': '2° período',
    '2023.1 (estou no 3º período)': '3° período',
}

resultado_resetado['periodo_curso'] = resultado_resetado['semestre'].map(semestre_para_periodo)
resultado_resetado = resultado_resetado[['semestre', 'periodo_curso', 'estudantes', 'percentual']]

print(resultado_resetado)
# Out:
#                        semestre periodo_curso  estudantes  percentual
# 0       2024.2 (estou cursando)    1° período          23   41.071429
# 1  2023.1 (estou no 3º período)    3° período          17   30.357143
# 2     2024.1 (semestre passado)    2° período          16   28.571429

# %% [markdown]
# É importante destacar que os 56 discentes que responderam ao formulário o fizeram de forma voluntária e anônima.

# %% [markdown]
# **1.2 - Compreendendo a base de dados**

# %% [markdown]
# Para obter uma visão geral rápida do conjunto de dados e entender suas principais características, vamos carregar as primeiras linhas do dataset.
#
# Essa abordagem nos permitirá explorar uma amostra representativa sem a necessidade de carregar todo o conjunto de dados, facilitando a análise inicial e identificando possíveis padrões ou problemas de qualidade dos dados.

# %%
df.head()
# Out:
#      Carimbo de data/hora Você concorda em participar dessa pesquisa?  \
# 0 2024-12-09 08:02:45.817                                         Sim
# 1 2024-12-09 08:05:16.961                                         Sim
# 2 2024-12-09 08:06:45.267                                         Sim
# 3 2024-12-09 08:07:04.591                                         Sim
# 4 2024-12-09 08:14:19.229                                         Sim
#
#   Em que semestre você cursou (ou está cursando) a disciplina de Anatomia Descritiva dos Animais Domésticos?  \
# 0                       2023.1 (estou no 3º período)
# 1                       2023.1 (estou no 3º período)
# 2                       2023.1 (estou no 3º período)
# 3                       2023.1 (estou no 3º período)
# 4                       2023.1 (estou no 3º período)
#
#    Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?  \
# ...

# %%
print(f'Total de colunas = {df.shape[1]}')
print(f'Total de linhas = {df.shape[0]}')
# Out:
# Total de colunas = 12
# Total de linhas = 56

# %% [markdown]
# Verificar valores nulos é crucial para garantir a qualidade dos dados, evitar distorções em modelos e garantir análises precisas, portanto verificaremos a **existência de valores nulos** nessas colunas selecionadas.

# %%
df.isnull().sum()
# Out:
# Carimbo de data/hora                                                                                                                                                 0
# Você concorda em participar dessa pesquisa?                                                                                                                          0
# Em que semestre você cursou (ou está cursando) a disciplina de Anatomia Descritiva dos Animais Domésticos?                                                           0
# Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?    0
# Sobre o conhecimento prático da osteologia equina:                                                                                                                   0
# ...

# %% [markdown]
# Com isso, podemos perceber que a coluna "Você já fez estágio(s) em alguma área da medicina veterinária?" **apresenta 1 valor nulo**, sendo assim, como a  resposta possível seria "Sim" ou "Não", para fins estatísticos escolhi preencher esse valor como "não".

# %%
# Preenchendo o valor nulo
df["Você já fez estágio(s) em alguma área da medicina veterinária?"] = df["Você já fez estágio(s) em alguma área da medicina veterinária?"].fillna("Não")

# %%
# Mostra quantos valores NaN existem
print(df['Você já fez estágio(s) em alguma área da medicina veterinária?'].isnull().sum())
# Out:
# 0

# %%
# Verificando as informações estatísticas
df['Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?'].describe()
# Out:
# count    56.000000
# mean      3.571429
# std       0.931414
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       4.000000
# max       5.000000
# Name: Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?, dtype: float64

# %% [markdown]
# O comando df.describe() irá gerar uma **estatística descritiva** das colunas numéricas do nosso dataframe, isso ajuda a entender a distribuição dos dados, identificar possíveis outliers e avaliar a dispersão dos valores.
#
# Nesse caso, fiz a análise da coluna "Confiança" porque ela mede a percepção dos alunos sobre seu conhecimento, o que é relevante para o objetivo da pesquisa.

# %% [markdown]
# **Com isso, podemos interpretar que:**

# %% [markdown]
# *   **Média (mean)**: A média de confiança é 3.57. Isso indica que, em média, os alunos se consideram moderadamente confiantes (entre 3 e 4 na escala de 1 a 5).
# *   **Desvio Padrão (std)**: O desvio padrão é 0.93, o que indica uma variação moderada nas respostas dos alunos.
# * **Valor mínimo (min)**: O valor mínimo é 1, o que significa que ao menos um aluno se sente completamente desconfortável ou sem confiança em seu conhecimento de osteologia.
# * **Percentis**:
#   * **25% (primeiro quartil)**: 25% dos alunos têm uma confiança de 3 ou menos.
#   * **50% (mediana)**: A mediana é 4, o que significa que metade dos alunos tem uma confiança abaixo de 4 e a outra metade, acima de 4.
#   * **75% (terceiro quartil)**: 75% dos alunos têm uma confiança de 4 ou menos, o que indica que a maior parte dos alunos se sente de forma moderada a bastante confiante.
# * **Valor máximo (max)**: O valor máximo é 5, o que significa que há alunos que se sentem totalmente confiantes em seu conhecimento sobre osteologia.

# %% [markdown]
# ## **Visualizando de forma gráfica**

# %% [markdown]
# Para ficar mais intuitivo e didático, vamos escolher por visualizar esses dados de forma gráfica.

# %% [markdown]
# Primeiro, para melhorar a legibilidade e a manipulação dos dados escolhi **renomear algumas colunas**.

# %%
df = df.rename(columns={'Em uma escala de 1 (não se sente confiante) a 5 (totalmente confiante), o quanto você se sente confiante em relação ao seu conhecimento em osteologia atualmente?': 'confiança_osteologia'})

# %%
df = df.rename(columns={'Em que semestre você cursou (ou está cursando) a disciplina de Anatomia Descritiva dos Animais Domésticos?': 'semestre'})

# %%
df = df.rename(columns={'Se tiver alguma dúvida e precisar revisar osteologia equina, por onde você começaria?': 'revisão_osteologia'})

# %%
df = df.rename(columns={'Para revisar o conteúdo prático de osteologia equina em qualquer época do curso e na vida profissional, você acha que': 'revisão_conteudo'})

# %%
df = df.rename(columns={'Você recomendaria o aplicativo de osteologia equina 3D do LAPA para outros estudantes e profissionais?': 'recomendação'})

# %% [markdown]
# Com esses detalhes finalizados, vamos analisar as diversas variáveis e compara-las entre si.
#
#
# É importante destacar que:
# * Nível 5 - totalmente confiante
# * Nível 4 - confiante
# * Nível 3 - parcialmente confiante
# * Nível 2 - pouco confiante
# * Nível 1 - nada confiante

# %% [markdown]
# ### **Visualização geral do nível de confiança em relação ao conhecimento em osteologia dos estudantes participantes.**

# %%
x = df['confiança_osteologia']

fig, ax = plt.subplots()

plt.grid(True)

ax.hist(x, bins=5, linewidth=0.5, edgecolor="black", color='#6c11b2')

plt.xlabel('Nível de Confiança')
plt.ylabel('Número de Estudantes')
plt.title('Nível de confiança em osteologia - Estudantes', pad=15)
plt.show()

# %% [markdown]
# Com isso, podemos concluir que:
#   * Os **níveis de confiança estão concentrados majoritariamente entre 3 e 4**, indicando que a maior parte dos alunos se percebe em um nível moderado de confiança.
#   * O histograma apresenta uma **leve assimetria negativa**, evidenciada por uma cauda à esquerda mais prolongada, o que mostra que existem alguns alunos com níveis de confiança mais baixos, embora em menor quantidade.

# %% [markdown]
# Para compreender melhor a **relação entre o período acadêmico e a confiança dos discentes** em osteologia, **analisaremos os gráficos individuais.**
#
# Essa abordagem nos permite identificar possíveis padrões de aprendizado ao longo da graduação, verificando se há um aumento na confiança conforme os alunos avançam no curso ou se existem desafios específicos em determinados períodos.

# %% [markdown]
# ### **Visualização dos estudantes do período 2024.2 (1° período)**

# %%
df_2024_2 = df[df['semestre'] == '2024.2 (estou cursando)']

contagem_confiança = df_2024_2['confiança_osteologia'].value_counts().sort_index()

contagem_confiança_percentual = (contagem_confiança / contagem_confiança.sum()) * 100

plt.figure(figsize=(8, 5))
ax = sns.barplot(x=contagem_confiança.index, y=contagem_confiança.values, color='#612d82')

max_val = contagem_confiança.values.max()
ax.set_ylim([0, max_val + 2])

for i, valor in enumerate(contagem_confiança_percentual):
    ax.text(i, contagem_confiança.values[i] + 0.5, f'{valor:.1f}%',
            ha='center', va='bottom', fontsize=11, fontweight='bold', color='black')

plt.xlabel('Nível de Confiança')
plt.ylabel('Número de Estudantes')
plt.title('Nível de confiança em osteologia - Estudantes do período 2024.2', pad=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# É importante destacar que os estudantes do **1° período (2024.2)**, quando comparados aos demais, tiveram um contato mais recente com a plataforma web 3D, já que **estavam cursando a disciplina de Anatomia Descritiva no momento da aplicação da pesquisa**.
#
# Percebemos que:
#
#   - Pouco mais da metade dos estudantes relataram sentir-se parcialmente confiantes em relação à osteologia.
#   - Dois estudantes afirmaram não se sentir confiantes no conhecimento em osteologia, mesmo após utilizarem a plataforma web 3D.

# %% [markdown]
# ### **Visualização dos estudantes do período 2024.1 (2° período)**

# %%
df_2024_1 = df[df['semestre'] == '2024.1 (semestre passado)']

contagem_confiança = df_2024_1['confiança_osteologia'].value_counts().sort_index()

contagem_confiança_percentual = (contagem_confiança / contagem_confiança.sum()) * 100

plt.figure(figsize=(8, 5))
ax = sns.barplot(x=contagem_confiança.index, y=contagem_confiança.values, color='#923ab5')

for i, valor in enumerate(contagem_confiança_percentual):
    ax.text(i, contagem_confiança.values[i] + 0.1, f'{valor:.1f}%', ha='center', fontsize=10, fontweight='bold', color='black')

plt.xlabel('Nível de Confiança')
plt.ylabel('Número de Estudantes')
plt.title('Nível de confiança em osteologia - Estudantes do período 2024.1')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Em relação aos estudantes do **2º período (2024.1)**, observamos uma distribuição variada nos níveis de confiança em osteologia.
#
#   - Apenas um estudante relatou um nível de confiança baixo (nível 2)
#   - A maioria se concentrou nos níveis intermediários e altos:
#     - quatro estudantes indicaram nível 3
#     - sete relataram nível 4 (maioria)
#     - quatro atingiram o nível máximo de confiança (nível 5)
#
# Esses dados sugerem **uma possível evolução na confiança dos alunos** em relação ao conhecimento osteológico à medida que avançam no curso.

# %% [markdown]
# ### **Visualização dos estudantes do período 2023.1 (3° período)**

# %%
df_2023_1 = df[df['semestre'] == '2023.1 (estou no 3º período)']

contagem_confiança = df_2023_1['confiança_osteologia'].value_counts().sort_index()

contagem_confiança_percentual = (contagem_confiança / contagem_confiança.sum()) * 100

plt.figure(figsize=(8, 5))
ax = sns.barplot(x=contagem_confiança.index, y=contagem_confiança.values, color='#b557a1')

max_val = contagem_confiança.values.max()
ax.set_ylim([0, max_val + 2])

for i, valor in enumerate(contagem_confiança_percentual):
    ax.text(i, contagem_confiança.values[i] + 0.5, f'{valor:.1f}%',
            ha='center', va='bottom', fontsize=11, fontweight='bold', color='black')

plt.xlabel('Nível de Confiança')
plt.ylabel('Número de Estudantes')
plt.title('Nível de confiança em osteologia - Estudantes do período 2023.1', pad=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# No **3º período (2023.1)**, observa-se uma distribuição distinta nos níveis de confiança em osteologia.
#
#   - Sete estudantes relataram um nível de confiança baixo (nível 3)
#   - A maioria apresentou níveis mais elevados:
#     - oito estudantes indicaram nível 4
#     - dois atingiram o nível máximo de
#       confiança (nível 5)
#
# Esse padrão sugere que, embora uma parcela significativa ainda tenha insegurança sobre o tema, **há um grupo considerável de alunos que se sente confiante no conhecimento adquirido.**

# %% [markdown]
# Com base nesses dados, ao **comparar os níveis de confiança em osteologia entre os estudantes do 1º, 2º e 3º períodos**, observamos que não há um aumento linear da confiança conforme os alunos avançam no curso.
#
# Embora o 2º período tenha apresentado uma maior concentração de estudantes nos níveis mais altos de confiança, o 3º período revelou um número expressivo de alunos com baixa segurança no tema.

# %% [markdown]
# Isso sugere que, apesar da progressão acadêmica, podem existir desafios específicos na consolidação do conhecimento em osteologia em determinados momentos do curso.
#
# Esses desafios podem estar relacionados à complexidade crescente dos conteúdos, à forma como o tema é revisitado em períodos posteriores ou à necessidade de reforço metodológico para garantir maior retenção e aplicação do conhecimento ao longo da formação.

# %% [markdown]
# ### **Preferências de Fontes de Estudo para Revisão de Osteologia Equina**

# %% [markdown]
# A escolha das **fontes de pesquisa para revisão de osteologia** é um fator crucial no processo de aprendizagem dos estudantes, pois reflete as ferramentas mais eficazes para a consolidação do conhecimento. Quando questionados sobre suas preferências, os estudantes indicaram diferentes recursos que priorizam em seus estudos.
#
# A seguir, apresento as respostas obtidas na pesquisa sobre as fontes mais utilizadas para revisão de osteologia equina.

# %%
contagem_conteudo = df['revisão_osteologia'].value_counts().sort_index()

contagem_conteudo_percentual = (contagem_conteudo / contagem_conteudo.sum()) * 100

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=contagem_conteudo.values, y=contagem_conteudo.index, color='purple')

max_val = contagem_conteudo.values.max()
ax.set_xlim([0, max_val + 2])

for i, valor in enumerate(contagem_conteudo_percentual):
    ax.text(contagem_conteudo.values[i] + 0.1, i, f'{valor:.1f}%',
            ha='left', va='center', fontsize=10, fontweight='bold', color='black')

plt.xlabel('Número de Estudantes')
plt.ylabel('Conteúdo de Revisão')
plt.title('Revisão de Conteúdo - Todos os Estudantes', pad=15)
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Com base nesses resultados, **percebemos que o uso da plataforma web 3D é a principal escolha dos alunos (55,9%)**. Em seguida, 35,6% dos participantes optaram pela coleção de fotos das peças anatômicas, que estão devidamente legendadas no site oficial do LAPA.
#
# O uso de atlas de anatomia e livros-texto, sejam impressos ou digitais, foi bastante menos frequente, com apenas 5,1% e 1,7% dos respondentes mencionando essas fontes, respectivamente.
#
# Além disso, 1,7% dos participantes citaram a utilização de peças físicas do LAPA como uma alternativa para a revisão de conteúdo.

# %% [markdown]
# Atrelado a isso, **foi questionado sobre quais métodos de revisão os discentes usariam e indicariam a outros estudantes e profissionais, seja em qualquer época do curso quanto durante a vida profissional**

# %%
contagem_conteudo_2 = df['revisão_conteudo'].value_counts().sort_index()
contagem_conteudo_2_percentual = (contagem_conteudo_2 / contagem_conteudo_2.sum()) * 100

respostas_com_quebra = [resp.replace(' fontes', '\nfontes') if 'fontes' in resp else resp for resp in contagem_conteudo_2.index]

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=contagem_conteudo_2.values, y=respostas_com_quebra, color='#6c11b2')

max_val = contagem_conteudo_2.values.max()
ax.set_xlim([0, max_val + 10])

for i, valor in enumerate(contagem_conteudo_2_percentual):
    ax.text(contagem_conteudo_2.values[i] + 0.5, i, f'{valor:.1f}%',
            ha='left', va='center', fontsize=11, fontweight='bold', color='black')

plt.xlabel('Número de Estudantes')
plt.ylabel('Conteúdo de Revisão')
plt.title('Revisão de Conteúdo 2 - Todos os Estudantes', pad=15)
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Com base nos dados apresentados, pode-se concluir que a **plataforma web de osteologia 3D** é considerado a principal ferramenta de revisão por uma maioria significativa de respondentes, com 50,8% das respostas indicando essa opção.
#
# Esses dados sugerem que, apesar do sucesso do aplicativo de osteologia 3D, ele pode ser mais eficaz quando combinado com outras fontes de conhecimento. A busca por uma abordagem multidimensional parece ser prevalente entre os estudantes, refletindo a necessidade de uma integração de diferentes métodos de aprendizado para uma compreensão mais profunda da osteologia.

# %% [markdown]
# Ao final do questionário, foi perguntado se os participantes **recomendavam a plataforma web de osteologia equina 3D do LAPA** para outros estudantes e profissionais, e se eles acreditavam que o processamento 3D de outras estruturas anatômicas seria importante para o enriquecimento do estudo de anatomia na UFAPE.

# %%
contagem_recomendacao = df['recomendação'].value_counts().sort_index()

contagem_recomendacao_percentual = (contagem_recomendacao / contagem_recomendacao.sum()) * 100

plt.figure(figsize=(8, 10))
ax = sns.barplot(x=contagem_recomendacao.index, y=contagem_recomendacao.values, color='purple')

max_val = contagem_recomendacao.values.max()
ax.set_ylim([0, max_val + 2])

for i, valor in enumerate(contagem_recomendacao_percentual):
    ax.text(i, contagem_recomendacao.values[i] + 0.5, f'{valor:.1f}%',
            ha='center', va='bottom', fontsize=11, fontweight='bold', color='black')

plt.xlabel('Resposta')
plt.ylabel('Número de Estudantes')
plt.title('Recomendação do Aplicativo 3D do LAPA para Outros Estudantes e Profissionais', pad=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# A grande maioria dos respondentes (98,3%) **afirmou que recomendaria o aplicativo de osteologia equina 3D do LAPA para outros estudantes e profissionais**, indicando uma opinião extremamente positiva sobre sua utilidade e eficácia.
#
# Apenas 1,7% dos participantes indicaram que não recomendariam a ferramenta.
#
# Esse dado reforça a **aceitação ampla da tecnologia** entre os estudantes e profissionais da área.

# %% [markdown]
# #**Teste de Hipótese**

# %% [markdown]
# Quando buscamos responder perguntas de forma precisa e embasada, frequentemente recorremos a **métodos estatísticos** que nos ajudam a avaliar a confiabilidade ou a probabilidade das respostas. Entre esses métodos, os **testes de hipótese são fundamentais**.
#
# Um **teste de hipótese** envolve a análise de duas declarações opostas sobre uma população, com o objetivo de determinar qual delas é mais consistente com os dados coletados em uma amostra.

# %% [markdown]
# **As hipóteses podem ser divididas em dois tipos principais:**
#
# * **Hipótese nula (H0)**: Assume que a afirmação inicial é verdadeira e que não há efeito ou diferença significativa. A hipótese nula é testada para verificar se podemos mantê-la ou rejeitá-la com base nos dados.
#
# * **Hipótese alternativa (H1)**: Representa a ideia de que há uma diferença ou efeito real, ou seja, que a hipótese nula deve ser rejeitada em algum nível de significância.

# %% [markdown]
# Um dos componentes chave de qualquer teste de hipótese é o **valor p**. Este valor é o que usamos para quantificar a evidência contra a hipótese nula. Com base no valor p, podemos decidir se rejeitamos ou não a hipótese nula. Se o valor p for menor que o nível de significância pré-determinado (geralmente 0,05), rejeitamos a hipótese nula em favor da hipótese alternativa. Caso contrário, não há evidência suficiente para rejeitar a hipótese nula.

# %%
from scipy.stats import chi2_contingency

# Criar a tabela de contingência
tabela_contingencia = pd.crosstab(df['semestre'], df['recomendação'])

# Exibir a tabela de contingência para visualização
print("Tabela de Contingência entre 'semestre' e 'recomendação':")
print(tabela_contingencia)

# Aplicar o teste Qui-Quadrado
stat, p_val, dof, expected = chi2_contingency(tabela_contingencia)

# Exibindo os resultados do teste Qui-Quadrado
print(f"\nResultado do Teste Qui-Quadrado:")
print(f"Estatística Qui-Quadrado: {stat}")
print(f"Valor p: {p_val}")
print(f"Grau de liberdade: {dof}")
print(f"\nValores esperados para cada célula da tabela de contingência:")
print(expected)

# Interpretação do valor p
if p_val < 0.05:
    print("\nConclusão: Existe uma relação significativa entre 'semestre' e 'confiança_osteologia'.")
else:
    print("\nConclusão: Não existe uma relação significativa entre 'semestre' e 'confiança_osteologia'.")

# IREI REVER ESSE TESTE AINDA
# Out:
# Tabela de Contingência entre 'semestre' e 'recomendação':
# recomendação                  Não  Sim
# semestre
# 2023.1 (estou no 3º período)    0   17
# 2024.1 (semestre passado)       0   16
# 2024.2 (estou cursando)         1   22
#
# Resultado do Teste Qui-Quadrado:
# Estatística Qui-Quadrado: 1.4608695652173915
# Valor p: 0.4816995099847905
# Grau de liberdade: 2
#
# Valores esperados para cada célula da tabela de contingência:
# [[ 0.30357143 16.69642857]
#  [ 0.28571429 15.71428571]
#  [ 0.41071429 22.58928571]]
#
# Conclusão: Não existe uma relação significativa entre 'semestre' e 'confiança_osteologia'.

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='semestre', hue='revisão_osteologia', palette=sns.color_palette("Purples_r", 5))
plt.title("Distribuição dos Métodos de Revisão por Semestre")
plt.xlabel("Semestre")
plt.ylabel("Número de Respostas")
plt.legend(title="Método de Revisão")
plt.show()
# Out:
# <ipython-input-46-c4044d52900f>:2: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.countplot(data=df, x='semestre', hue='revisão_osteologia', palette=sns.color_palette("Purples_r", 5))

# %% [markdown]
# # **Conclusão**
#
# Pode-se concluir, portanto, que o **uso do site [Hub Anatomia 3D](https://hubanatomia.ufape.edu.br) desenvolvido pelo LAPA** influencia positivamente na percepção e na retenção do conhecimento acerca da anatomia veterinária.
#
# Seu papel de **modernizar o ensino** e transformar as metodologias educacionais em algo mais prático e visual promove um maior engajamento com o conteúdo abordado.
#
# Além disso, **é indicado que haja uma combinação de tecnologias**, como o site de anatomia 3D ([Hub Anatomia 3D](https://hubanatomia.ufape.edu.br)), com outras abordagens tradicionais, como aulas práticas com peças físicas. Feito isso, estudantes que não tenham um nível de confiança alto apenas com o uso do site, possam atingir melhores resultados.
#
# Dessa forma, novos estudos podem ser realizados a fim de avaliar o impacto na retenção de conhecimento anatômico via abordagens híbridas.
#
# Por fim, **a integração de tecnologias inovadoras e avançadas no processo formativo de médicos veterinários**, os prepara de forma mais completa frente a um mercado cada vez mais exigente no quesito tecnológico e na busca de soluções mais práticas.

# %% [markdown]
# # **Obrigada!**

# %% [markdown]
# Chegamos ao fim dessa simples análise de dados que foi estruturada em seis fases principais como dito no inicio desse notebook.
#
#   * ✅ Entendimento do problema
#   * ✅ Coleta de Dados
#   * ✅ Explorar dados
#   * ✅ Análise de Dados
#   * ✅ Interpretação/Visualização
#   * ✅ Compartilhar/Ação

# %% [markdown]
# Esse estudo cumpriu as seis fases previstas e contribuiu para uma melhor compreensão sobre o impacto e a utilização da plataforma web 3D entre os estudantes e profissionais da área.
#
# Podemos continuar avançando no projeto, criando mais gráficos e realizando mais análises estatísticas. No entanto, para o objetivo que estabelecemos, acredito que o que já foi feito até aqui é suficiente.

# %% [markdown]
# Agradeço pela atenção dedicada à leitura desta análise.
#
# Caso tenha interesse em continuar a conversa ou compartilhar insights, fico à disposição para contato por e-mail ou através do meu LinkedIn.

# %% [markdown]
# [![Gmail: Joana Trindade](https://img.shields.io/badge/Gmail-D14836?style=for-the-badge&logo=gmail&logoColor=white&link=mailto:joanatrindade58@gmail.com)](mailto:joanatrindade58@gmail.com)
#
# [![Linkedin: Joana Trindade](https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white&link=https://www.linkedin.com/in/joanatrindade-/)](https://www.linkedin.com/in/joanatrindade-/
# )

# %% [markdown]
# # **Referências**

# %% [markdown]
# [Pandas](https://pandas.pydata.org/)
#
# [Matplotlib](https://matplotlib.org/)
#
# [Seaborn](https://seaborn.pydata.org/)
#
# ELIAS N. S. R., PEREIRA, H. C. S., LISBOA NETO, A. F. S., SILVEIRA, E. E., SANTOS, A. C, & ASSIS NETO, A. C. (2021). Bioprinting of 3D anatomical models of flat and long thoracic limb bones of domestic cats (Felis catus Linnaeus, 1758). Brazilian Journal of Veterinary Medicine, 43, e106020.
#
#
# PETERSON, D.C.; MLYNARCZYK, G.S.A. Analysis of traditional versus three-dimensional augmented curriculum on anatomical learning outcome measures. American Association of Anatomists. v. 9 p. 529-536, 2016.
#
# SANTANA, A. L. S.; UZÊDA, S. Q.; SOBRINHO, F. P. G.; TRZAN, A. L. S. Importância e perfil do estudo da anatomia na formação médica: Percepção dos estudantes e desafios. Scientia: Revista Científica Multidisciplinar, [S. l.], v. 9, n. 2, p. 124–136, 2024.
